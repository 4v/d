# %%
import tushare as ts
import pandas as pd

filename='data/test2.h5'
d = ts.get_tick_data('600848',date='2018-05-18')
print(type(d))
print(len(d))
h5 = pd.HDFStore(filename,'w')
h5['data'] = d
h5.close()

h5 = pd.HDFStore(filename,'r')
e = h5['data']
h5.close()
print(type(e))
#print(len(e))
#print(e)

info=ts.get_stock_basics()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 2292
# <class 'pandas.core.frame.DataFrame'>

# %%
print(info)
# Out:
#          name industry area       pe  outstanding  totals  totalAssets  \
# code
# 300746    N汉嘉     建筑施工   浙江    36.00         0.53    2.10     84655.75
# 002708   光洋股份     汽车配件   江苏    59.21         2.40    4.69    235143.66
# 002725   跃岭股份     汽车配件   浙江   179.97         1.10    2.56    111422.38
# 300471   厚普股份     专用机械   四川     0.00         2.23    3.71    267486.53
# 603066   音飞储存     仓储物流   江苏    78.61         1.38    3.02    117683.97
# 300643   万通智控     汽车配件   浙江  1991.42         0.71    2.00     48480.46
# 300745   欣锐科技     汽车配件   深圳    20.66         0.29    1.15    112515.45
# 300580    贝斯特     汽车配件   江苏    33.83         0.66    2.00    153087.30
# 002722   金轮股份     纺织机械   江苏    43.68         1.11    1.75    267063.66
# 300720   海川智能     电器仪表   广东   114.29         0.18    0.72     46308.18
# 603386   广东骏亚      元器件   广东    88.23         0.51    2.02    118533.05
# 300162   雷曼股份      元器件   深圳  1129.03         2.19    3.50    130910.47
# ...
