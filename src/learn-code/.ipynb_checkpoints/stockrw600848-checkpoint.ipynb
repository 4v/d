# %%
import tushare as ts
import pandas as pd

d = ts.get_tick_data('600848',date='2018-05-18')
print(type(d))
print(len(d))
h5 = pd.HDFStore('/Users/hexj/hexj/db/data/stock/test2.h5','w')
h5['data'] = d
h5.close()

h5 = pd.HDFStore('/Users/hexj/hexj/db/data/stock/test2.h5','r')
e = h5['data']
h5.close()
print(type(e))
#print(len(e))
#print(e)

info=ts.get_stock_basics()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 2292
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-18fcd44bce4f> in <module>()
#       5 print(type(d))
#       6 print(len(d))
# ----> 7 h5 = pd.HDFStore('/Users/hexj/hexj/db/data/stock/test2.h5','w')
#       8 h5['data'] = d
#       9 h5.close()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     464         self._fletcher32 = fletcher32
#     465         self._filters = None
# --> 466         self.open(mode=mode, **kwargs)
#     467
#     468     @property
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/pytables.py in open(self, mode, **kwargs)
#     603
#     604         try:
# --> 605             self._handle = tables.open_file(self._path, self._mode, **kwargs)
# ...

# %%
print(info)
# Out:
#          name industry area       pe  outstanding  totals  totalAssets  \
# code
# 300135   宝利国际     化工原料   江苏   336.09         9.22    9.22    308387.34
# 600583   海油工程     石油开采   天津     0.00        44.21   44.21   2677861.75
# 000595   宝塔实业     机械基件   宁夏   162.93         7.45    7.64    199641.75
# 002172   澳洋科技       化纤   江苏    50.13         5.69    7.35    619664.13
# 002554    惠博普     石油开采   北京    32.80         8.36   10.71    466008.75
# 002865   钧达股份     汽车配件   海南    49.39         0.38    1.20    171108.31
# 600339   中油工程     石油加工   新疆     0.00        15.52   55.83   9267700.00
# 300559   佳发安泰     软件服务   四川   156.14         0.76    1.40     79582.96
# 300471   厚普股份     专用机械   四川     0.00         2.23    3.71    267486.53
# 002828   贝肯能源     石油开采   新疆     0.00         0.58    1.20    141358.09
# 603036   如通股份     专用机械   江苏   253.07         0.51    2.03    107677.77
# 300644   南京聚隆       塑料   江苏   147.76         0.16    0.64    105202.95
# ...
