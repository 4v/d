# %%
# -*- coding: utf-8 -*-  
  
#%% 导入包  
import tushare as ts  
import pandas as pd  
import matplotlib.pyplot as plt  
  
#%% 获取中国平安三年内K线数据  
ZGPA=ts.get_hist_data('000001')  
ZGPA.index=pd.to_datetime(ZGPA.index)  
  
#%% 相关指数  
print(ZGPA.tail())  
plt.plot(ZGPA['close'],label='ClosePrice')
plt.plot(ZGPA['ma5'],label='MA5')
plt.plot(ZGPA['ma20'],label='MA20')
plt.legend()  
plt.xlabel('日期')  
plt.ylabel('股价')  
plt.title('中国平安收盘价，MA5，MA20时间序列')  
            
#%% 获取中国平安全部历史数据  
ZGPA_all=ts.get_h_data('000001',start='2018-01-01')  
ZGPA_all.index=pd.to_datetime(ZGPA_all.index)  
  
#%% 相关指数  
print(ZGPA_all.tail())  
plt.plot(ZGPA_all['close'],label='收盘价')  
plt.legend()  
plt.xlabel('日期')  
plt.ylabel('股价')  
plt.title('中国平安收盘价时间序列(2006至今)')  
  
#%% 计算收益率  
ZPGA_Return=((ZGPA_all['close']-ZGPA_all['close'].shift(1))/ZGPA_all['close'].shift(1)).dropna() #收益率
# Out:
#              open   high  close    low      volume  price_change  p_change  \
# date
# 2015-05-26  16.63  16.70  16.62  16.28  2792208.75          0.02      0.12
# 2015-05-25  16.35  16.71  16.60  16.35  2730369.50          0.33      2.03
# 2015-05-22  15.91  16.30  16.27  15.82  2621907.75          0.48      3.04
# 2015-05-21  15.80  15.89  15.79  15.62  1405846.62          0.05      0.32
# 2015-05-20  16.01  16.15  15.74  15.60  2589667.00          0.15      0.96
#
#                ma5    ma10    ma20       v_ma5      v_ma10      v_ma20  \
# date
# 2015-05-26  16.204  16.204  16.204  2427999.92  2427999.92  2427999.92
# 2015-05-25  16.100  16.100  16.100  2336947.72  2336947.72  2336947.72
# 2015-05-22  15.933  15.933  15.933  2205807.12  2205807.12  2205807.12
# 2015-05-21  15.765  15.765  15.765  1997756.81  1997756.81  1997756.81
# 2015-05-20  15.740  15.740  15.740  2589667.00  2589667.00  2589667.00
#
#             turnover
# date
# 2015-05-26      2.37
# 2015-05-25      2.31
# 2015-05-22      2.22
# 2015-05-21      1.19
# 2015-05-20      2.19
# [Getting data:]#             open   high  close    low       volume        amount
# date
# 2018-01-08  13.30  13.34  13.01  12.91  215862081.0  2.806099e+09
# 2018-01-05  13.26  13.40  13.35  13.20  121031272.0  1.603290e+09
# 2018-01-04  13.37  13.42  13.30  13.18  185450948.0  2.454544e+09
# 2018-01-03  13.78  13.91  13.38  13.25  296249838.0  4.006221e+09
# 2018-01-02  13.40  13.98  13.75  13.37  208159255.0  2.856544e+09

# %%
plt.plot(ZPGA_Return)

print('中国平安的平均日收益率：',ZPGA_Return.mean(),'\n中国平安的收益率标准差：', ZPGA_Return.std())
# Out:
# 中国平安的平均日收益率： 0.0027602242627401334
# 中国平安的收益率标准差： 0.022620770592510497
